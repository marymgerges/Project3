# %%
# Import necessary libraries
from pymongo import MongoClient
# Set the data rate limit directly within the notebook
from IPython.display import display, HTML
display(HTML("<script>Jupyter.notebook.kernel.execute('from notebook.services.config import ConfigManager; cm = ConfigManager(); cm.update(\"notebook\", {\"limit_output\": 10000000})')</script>"))
# MongoDB connection string
connection_string = "mongodb+srv://p3_ucb:ucb@petdata0.isr3dox.mongodb.net/"
# Connect to the MongoDB cluster
client = MongoClient(connection_string)
# Access the specific database (replace 'mydatabase' with your actual database name)
db = client.animal_shelter
# Access the specific collection
collection = db.pet
# Fetch data from the collection
cursor = collection.find({})
data_list = []
# Iterate over the cursor and print each document
for document in cursor:
    print(document)
    data_list.append(document)
# Out:
# <script>Jupyter.notebook.kernel.execute('from notebook.services.config import ConfigManager; cm = ConfigManager(); cm.update("notebook", {"limit_output": 10000000})')</script>
# {'_id': ObjectId('65f12512067238e11e4b173f'), 'animal_id': 'A626674', 'animal_name': None, 'animal_type': 'CAT', 'primary_color': 'BRN TABBY', 'secondary_color': None, 'sex': 'Male', 'dob': '2019-04-14', 'intake_date': '2019-05-19', 'intake_cond': 'UNDER AGE/WEIGHT', 'intake_type': 'STRAY', 'intake_subtype': 'OTC', 'reason': None, 'outcome_date': '2019-05-25', 'crossing': '5800 BLK JAYMILLS AVE, LONG BEACH, CA 90805', 'jurisdiction': 'LONG BEACH', 'outcome_type': 'TRANSFER', 'outcome_subtype': 'SPCALA', 'latitude': 33.8605961, 'longitude': -118.1923925, 'intake_is_dead': 'Alive on Intake', 'outcome_is_dead': 'FALSE', 'was_outcome_alive': 1, 'geopoint': {'lon': -118.1923925, 'lat': 33.8605961}}
# ...

# %%
ls=data_list.copy()
for i in range(len(ls)):
    #data clean
    ls[i]['intake_date'] = str(ls[i]['intake_date']).split('-')[0]  # Only keep the year
    ls[i]['outcome_date'] = str(ls[i]['outcome_date']).split('-')[0]  # Only keep the year
    # Remove the fields that are not needed
    ls[i].pop('animal_id', None) # Remove animal_id
    ls[i].pop('animal_name', None) # Remove animal_name
    ls[i].pop('secondary_color', None)# Remove secondary_color
    ls[i].pop('dob', None) # Remove dob
    ls[i].pop('reason', None) # Remove reason
    ls[i].pop('intake_subtype', None) # Remove intake_subtype
    print(ls[i])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# {'_id': ObjectId('65f12521067238e11e4b6cb1'), 'animal_type': 'CAT', 'primary_color': 'WHITE', 'sex': 'Spayed', 'intake_date': '2021', 'intake_cond': 'ILL MODERATETE', 'intake_type': 'STRAY', 'outcome_date': '2021', 'crossing': '12400 MILES ST, CERRITOS, CA 90703', 'jurisdiction': 'CERRITOS', 'outcome_type': 'FOSTER TO ADOPT', 'outcome_subtype': None, 'latitude': 33.8475833, 'longitude': -118.0677496, 'intake_is_dead': 'Alive on Intake', 'outcome_is_dead': 'FALSE', 'was_outcome_alive': 1, 'geopoint': {'lon': -118.0677496, 'lat': 33.8475833}}
# ...

# %%
import json
filename = "data.json"
#sava data
with open(filename, 'w') as f:
    json.dump(ls, f, cls=JSONEncoder)

# %%
import json
with open('data.json', 'r') as file:
    data = json.load(file)
print(data[0])
# Out:
# {'_id': '65f12512067238e11e4b173f', 'animal_type': 'CAT', 'primary_color': 'BRN TABBY', 'sex': 'Male', 'intake_date': '2019', 'intake_cond': 'UNDER AGE/WEIGHT', 'intake_type': 'STRAY', 'outcome_date': '2019', 'crossing': '5800 BLK JAYMILLS AVE, LONG BEACH, CA 90805', 'jurisdiction': 'LONG BEACH', 'outcome_type': 'TRANSFER', 'outcome_subtype': 'SPCALA', 'latitude': 33.8605961, 'longitude': -118.1923925, 'intake_is_dead': 'Alive on Intake', 'outcome_is_dead': 'FALSE', 'was_outcome_alive': 1, 'geopoint': {'lon': -118.1923925, 'lat': 33.8605961}}
